# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.utils import to_categorical
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# Load the MNIST dataset

# %%
(train_data,train_target),(test_data,test_target) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %% [markdown]
# Visualize the dataset

# %%
fig, axs = plt.subplots(2, 5, figsize=(16,8))
random_numbers = np.random.randint(0, 60000, 10)
print('Target labels: ',train_target[random_numbers])
for idx, ax in enumerate(axs.ravel()):
    ax.imshow(train_data[random_numbers[idx]],cmap='gray')
plt.show()
# Out:
# Target labels:  [5 8 3 2 0 0 6 8 8 9]

# %% [markdown]
# Pre-processing stage

# %%
new_train_data = train_data/255.0
new_test_data=test_data/255.0

new_train_target = to_categorical(train_target)
new_test_target = to_categorical(test_target)

# %% [markdown]
# Create the Model architecture

# %%
model=Sequential()

model.add(Flatten(input_shape=(28,28)))

model.add(Dense(64,activation='relu'))
model.add(Dense(64,input_dim=64,activation='relu'))
model.add(Dense(32,input_dim=64,activation='relu'))
model.add(Dense(10,input_dim=32,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        50,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 56,810 (221.91 KB)
#  Trainable params: 56,810 (221.91 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Train the model

# %%
train_info = model.fit(new_train_data , new_train_target , epochs = 10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8444 - loss: 0.5107
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9591 - loss: 0.1337
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9718 - loss: 0.0935
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9770 - loss: 0.0729
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9804 - loss: 0.0586
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9853 - loss: 0.0468
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9867 - loss: 0.0412
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9872 - loss: 0.0369
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9898 - loss: 0.0300
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9906 - loss: 0.0281

# %% [markdown]
# Plot the loss and accuracy graphs

# %%
plt.plot(train_info.history['loss'])
plt.xlabel('epochs')
plt.ylabel('loss')
plt.title('Model loss')
plt.show()

# %%
plt.plot(train_info.history['accuracy'])
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.title('Model accuracy')
plt.show()

# %% [markdown]
# Test the performance of Model

# %%
loss, acc = model.evaluate(new_test_data , new_test_target)
print(f'Loss of the Test dataset is: {loss}\nAccuracy of the test dataset is: {acc}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9690 - loss: 0.1207
# Loss of the Test dataset is: 0.10180060565471649
# Accuracy of the test dataset is: 0.9747999906539917

# %%
# ===== Part (a) - Improve model test accuracy =====

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# Build improved model
improved_model = Sequential()
improved_model.add(Flatten(input_shape=(28, 28)))
improved_model.add(Dense(128, activation='relu'))
improved_model.add(Dropout(0.2))
improved_model.add(Dense(128, activation='relu'))
improved_model.add(Dropout(0.2))
improved_model.add(Dense(64, activation='relu'))
improved_model.add(Dense(10, activation='softmax'))

# Compile with adjusted learning rate
optimizer = Adam(learning_rate=0.001)
improved_model.compile(loss='categorical_crossentropy',
                       optimizer=optimizer, metrics=['accuracy'])

# Train
train_info = improved_model.fit(new_train_data, new_train_target,
                                epochs=20, batch_size=64,
                                validation_data=(new_test_data, new_test_target),
                                verbose=1)

# Plot loss
plt.plot(train_info.history['loss'], label='Train Loss')
plt.plot(train_info.history['val_loss'], label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Improved Model Loss')
plt.legend()
plt.show()

# Plot accuracy
plt.plot(train_info.history['accuracy'], label='Train Accuracy')
plt.plot(train_info.history['val_accuracy'], label='Val Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Improved Model Accuracy')
plt.legend()
plt.show()

# Evaluate
loss, acc = improved_model.evaluate(new_test_data, new_test_target, verbose=0)
print(f'Loss on test data: {loss:.4f}')
print(f'Accuracy on test data: {acc:.4f}')
# Out:
# Epoch 1/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.8027 - loss: 0.6249 - val_accuracy: 0.9572 - val_loss: 0.1421
# Epoch 2/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9483 - loss: 0.1657 - val_accuracy: 0.9670 - val_loss: 0.1078
# Epoch 3/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9615 - loss: 0.1260 - val_accuracy: 0.9747 - val_loss: 0.0854
# Epoch 4/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9689 - loss: 0.1004 - val_accuracy: 0.9728 - val_loss: 0.0858
# Epoch 5/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9734 - loss: 0.0848 - val_accuracy: 0.9746 - val_loss: 0.0833
# Epoch 6/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9761 - loss: 0.0737 - val_accuracy: 0.9772 - val_loss: 0.0759
# Epoch 7/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9765 - loss: 0.0720 - val_accuracy: 0.9779 - val_loss: 0.0703
# Epoch 8/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9793 - loss: 0.0680 - val_accuracy: 0.9760 - val_loss: 0.0754
# Epoch 9/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9792 - loss: 0.0652 - val_accuracy: 0.9797 - val_loss: 0.0692
# Epoch 10/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.9815 - loss: 0.0578 - val_accuracy: 0.9787 - val_loss: 0.0744
# Epoch 11/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9832 - loss: 0.0539 - val_accuracy: 0.9795 - val_loss: 0.0712
# Epoch 12/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9836 - loss: 0.0512 - val_accuracy: 0.9803 - val_loss: 0.0703
# Epoch 13/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9848 - loss: 0.0483 - val_accuracy: 0.9787 - val_loss: 0.0779
# Epoch 14/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9843 - loss: 0.0482 - val_accuracy: 0.9812 - val_loss: 0.0680
# Epoch 15/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9866 - loss: 0.0417 - val_accuracy: 0.9785 - val_loss: 0.0823
# Epoch 16/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9866 - loss: 0.0425 - val_accuracy: 0.9804 - val_loss: 0.0758
# Epoch 17/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9871 - loss: 0.0391 - val_accuracy: 0.9788 - val_loss: 0.0781
# Epoch 18/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9862 - loss: 0.0431 - val_accuracy: 0.9803 - val_loss: 0.0792
# Epoch 19/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9876 - loss: 0.0370 - val_accuracy: 0.9805 - val_loss: 0.0720
# Epoch 20/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9882 - loss: 0.0351 - val_accuracy: 0.9811 - val_loss: 0.0747
# Loss on test data: 0.0747
# Accuracy on test data: 0.9811

# %%
# ===== Part (b) - Add L1 and L2 regularization =====

from tensorflow.keras import regularizers

# Build model with regularization
reg_model = Sequential()
reg_model.add(Flatten(input_shape=(28, 28)))
reg_model.add(Dense(128, activation='relu',
                    kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001)))
reg_model.add(Dense(128, activation='relu',
                    kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001)))
reg_model.add(Dense(64, activation='relu',
                    kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001)))
reg_model.add(Dense(10, activation='softmax'))

# Compile
reg_model.compile(loss='categorical_crossentropy',
                  optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

# Train
reg_train_info = reg_model.fit(new_train_data, new_train_target,
                               epochs=20, batch_size=64,
                               validation_data=(new_test_data, new_test_target),
                               verbose=1)

# Evaluate
loss, acc = reg_model.evaluate(new_test_data, new_test_target, verbose=0)
print(f'Regularized Model Loss: {loss:.4f}')
print(f'Regularized Model Accuracy: {acc:.4f}')
# Out:
# Epoch 1/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8216 - loss: 2.8285 - val_accuracy: 0.9114 - val_loss: 0.9582
# Epoch 2/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9114 - loss: 0.8850 - val_accuracy: 0.9235 - val_loss: 0.7103
# Epoch 3/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9269 - loss: 0.6832 - val_accuracy: 0.9309 - val_loss: 0.6016
# Epoch 4/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9339 - loss: 0.5932 - val_accuracy: 0.9344 - val_loss: 0.5538
# Epoch 5/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9371 - loss: 0.5474 - val_accuracy: 0.9366 - val_loss: 0.5144
# Epoch 6/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9409 - loss: 0.5140 - val_accuracy: 0.9449 - val_loss: 0.4830
# Epoch 7/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9432 - loss: 0.4861 - val_accuracy: 0.9484 - val_loss: 0.4556
# Epoch 8/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9436 - loss: 0.4746 - val_accuracy: 0.9454 - val_loss: 0.4515
# Epoch 9/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9461 - loss: 0.4530 - val_accuracy: 0.9393 - val_loss: 0.4479
# Epoch 10/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9463 - loss: 0.4436 - val_accuracy: 0.9470 - val_loss: 0.4285
# Epoch 11/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9453 - loss: 0.4382 - val_accuracy: 0.9475 - val_loss: 0.4252
# Epoch 12/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9466 - loss: 0.4283 - val_accuracy: 0.9491 - val_loss: 0.4134
# Epoch 13/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9475 - loss: 0.4228 - val_accuracy: 0.9514 - val_loss: 0.4060
# Epoch 14/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9489 - loss: 0.4111 - val_accuracy: 0.9519 - val_loss: 0.3987
# Epoch 15/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9513 - loss: 0.4046 - val_accuracy: 0.9527 - val_loss: 0.3892
# Epoch 16/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9500 - loss: 0.4027 - val_accuracy: 0.9537 - val_loss: 0.3853
# Epoch 17/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9524 - loss: 0.3932 - val_accuracy: 0.9584 - val_loss: 0.3685
# Epoch 18/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9510 - loss: 0.3920 - val_accuracy: 0.9516 - val_loss: 0.3840
# Epoch 19/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9509 - loss: 0.3878 - val_accuracy: 0.9496 - val_loss: 0.3910
# Epoch 20/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9514 - loss: 0.3900 - val_accuracy: 0.9558 - val_loss: 0.3697
# Regularized Model Loss: 0.3697
# Regularized Model Accuracy: 0.9558

# %%
# ===== Part (c) - Confusion Matrix =====

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
import matplotlib.pyplot as plt

# Predict classes for the test set
y_pred_probs = improved_model.predict(new_test_data)
y_pred_classes = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(new_test_target, axis=1)

# Create confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)

# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title('Confusion Matrix - Improved Model')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %% [markdown]
# Save the model weights

# %%
model.save_weights('MNIST_WEIGHTS_V1.h5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1574029529.py in <cell line: 0>()
# ----> 1 model.save_weights('MNIST_WEIGHTS_V1.h5')
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_api.py in save_weights(model, filepath, overwrite, max_shard_size, **kwargs)
#     225     filepath_str = str(filepath)
#     226     if max_shard_size is None and not filepath_str.endswith(".weights.h5"):
# --> 227         raise ValueError(
#     228             "The filename must end in `.weights.h5`. "
#     229             f"Received: filepath={filepath_str}"
#
# ValueError: The filename must end in `.weights.h5`. Received: filepath=MNIST_WEIGHTS_V1.h5
